# %%
# %matplotlib inline

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("..")
from src.model import LiteModel
from src.util import predict_bounding_box, draw_bounding_box
import mss

# %%
with open("../assets/model/quantized-model.tflite", "rb") as file:
    model = LiteModel(file.read())

# %%
image = Image.open("../assets/data/samples/sample_2.JPEG")
image = np.array(image)
plt.imshow(image)

# %%
box = predict_bounding_box(model, image)
output = draw_bounding_box(image, box)
plt.imshow(output)

# %%
rect = {'left': 677, 'top': 289, 'width': 325, 'height': 500}

with mss.mss() as screen:
    image = screen.grab(rect)
image = np.array(image)
image = cv2.cvtColor(image, cv2.COLOR_BGRA2RGB)

# %%
image.shape
# Out:
# (500, 325, 3)

# %%
plt.imshow(image)

# %%
box = predict_bounding_box(model, image)
print(box)
output = draw_bounding_box(image, box)
plt.imshow(output)
# Out:
# [0.5223524  0.529414   0.2450474  0.20798226]
